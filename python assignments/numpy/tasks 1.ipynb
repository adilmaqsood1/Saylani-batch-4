# %% [markdown]
# # task 1

# %%
! pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np

# Load the image using imread()
image_path = 'C:\\Users\\Lenovo\\Downloads\\image.jpeg'  # Replace with the actual path to your image
image = mpimg.imread(image_path)

# Convert the image to a NumPy array
image_array = np.array(image)
image_array
# Out:
# array([[[207, 216, 199],
#         [205, 214, 197],
#         [209, 218, 201],
#         ...,
#         [250, 250, 242],
#         [249, 250, 242],
#         [249, 252, 243]],
#
#        [[206, 214, 199],
#         [204, 212, 197],
#         [205, 213, 198],
#         ...,
#         [249, 249, 241],
#         [250, 250, 242],
#         [249, 250, 242]],
#
#        [[196, 204, 189],
#         [196, 204, 189],
#         [195, 203, 188],
#         ...,
#         [252, 248, 239],
#         [251, 248, 241],
#         [252, 249, 242]],
#
#        ...,
#
#        [[  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3],
#         ...,
#         [ 52,  52,  42],
#         [ 52,  52,  42],
#         [ 52,  52,  42]],
#
#        [[  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3],
#         ...,
#         [ 50,  50,  40],
#         [ 50,  50,  40],
#         [ 50,  50,  40]],
#
#        [[  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3],
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# Load the image using imread()
image_path = 'C:\\Users\\Lenovo\\Downloads\\image.jpeg'  # Replace with the actual path to your image
image = mpimg.imread(image_path)

# Convert the image to a NumPy array
image_array = np.array(image)

# Display the image using Matplotlib
plt.imshow(image_array)
plt.axis('ON')  # Remove axis labels
plt.show()

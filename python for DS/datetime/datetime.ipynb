# %% [markdown]
# # datetime package

# %%
import datetime

# %%
today= datetime.datetime.()

print(today.year)
print(today.month)
print(today.day)
print(today.hour)
print(today.minute)
print(today.second)
# Out:
#   File "C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9524\2916369064.py", line 1
#     today= datetime.datetime.()
#                              ^
# SyntaxError: invalid syntax

# %%
from datetime import timedelta
delta = timedelta(
    days=30,
    seconds=27,
    microseconds=10,
    milliseconds=29000,
    minutes=5,
    hours=8,
    weeks=2)
delta
# Out:
# datetime.timedelta(days=44, seconds=29156, microseconds=10)

# %%
display(today)
display(today + delta)
display(today - delta)
# Out:
# datetime.datetime(2023, 5, 17, 14, 48, 2, 542682)
# datetime.datetime(2023, 7, 20, 22, 53, 58, 542692)
# datetime.datetime(2023, 3, 14, 6, 42, 6, 542672)

# %%
from datetime import timedelta
time = timedelta(

       minutes=10,
       hours=10,
       weeks=10)
delta
# Out:
# datetime.timedelta(days=44, seconds=29156, microseconds=10)

# %%
today= datetime.datetime.today()
print(today)
from datetime import timedelta
years = timedelta(days=23, month = 8, years = 2001)

print(delta - today )
# Out:
# 2023-05-17 15:27:17.970991
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9524\845560724.py in <module>
#       2 print(today)
#       3 from datetime import timedelta
# ----> 4 years = timedelta(days=23, month = 8, years = 2001)
#       5
#       6 print(delta - today )
#
# TypeError: 'month' is an invalid keyword argument for __new__()

# %%
from datetime import timedelta
year = timedelta(days=365)
another_year = timedelta(weeks=40, days=84, hours=23,
                         minutes=50, seconds=600)
year == another_year
True
year.total_seconds()
# Out:
# 31536000.0

# %%
import time
from datetime import date
today = date.today()
today
datetime.date(2001, 8, 23)
today == date.fromtimestamp(time.time())
True
my_birthday = date(today.year, 6, 24)
if my_birthday < today:
    my_birthday = my_birthday.replace(year=today.year + 1)
my_birthday
datetime.date(2001, 8, 23)
time_to_birthday = abs(my_birthday - today)
time_to_birthday.days
# Out:
# 38

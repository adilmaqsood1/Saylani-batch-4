# %% [markdown]
# # Assignment
#    ``` sort dictionary based on their values. ```

# %%
d= {'waleed': 4, 'adil': 2, 'khan': 6, 'maqsood': 3}


sorted_d = sorted(d.items(), key=lambda item: item[1])

print(sorted_dict)
# Out:
# [('adil', 2), ('maqsood', 3), ('waleed', 4), ('khan', 6)]

# %%
l = [[1,'a','Z'],
    [2,'b','Y'],
    [3,'c',"X"]]
l
sorted(l, key=lambda x:x[1])
# Out:
# [[1, 'a', 'Z'], [2, 'b', 'Y'], [3, 'c', 'X']]

# %%
l = {'course' : 3 , 'name' : 1 , 'adil' : 2 }
sorted(l, key=lambda x:x[1])
# Out:
# ['name', 'adil', 'course']

# %%
my_dict = {'waleed': 4, 'adil': 2, 'khan': 6, 'maqsood': 3}

sorted(my_dict, key=lambda x:x[3])
# Out:
# ['waleed', 'adil', 'khan', 'maqsood']

# %%
def get_data(file_name):
    import pandas as pd
    df = pd.read_csv(f"https://raw.githubusercontent.com/simonwarchol/NBA-Height-Weight/master/CSVs/{file_name}.csv")
    display(df)
    return df

abc = get_data("total")
# Out:
#                     Name   Height (Inches)  Height(Feet-Inches)   Weight
# 0             A.C. Green                81                  6-9      220
# 1          A.J. Bramlett                82                 6-10      227
# 2           A.J. English                75                  6-3      175
# 3            A.J. Guyton                73                  6-1      180
# 4             A.J. Price                74                  6-2      181
# ...                  ...               ...                  ...      ...
# 3411      Zeljko Rebraca                84                  7-0      257
# 3412         Zelmo Beaty                81                  6-9      225
# 3413     Zendon Hamilton                83                 6-11      250
# 3414      Zoran Planinic                79                  6-7      195
# 3415  Zydrunas Ilgauskas                87                  7-3      238
#
# [3416 rows x 4 columns]

# %%
from pycaret.datasets import get_data
data = get_data('total')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9572\3807376887.py in <module>
#       1 from pycaret.datasets import get_data
# ----> 2 data = get_data('total')
#
# ~\AppData\Roaming\Python\Python39\site-packages\pycaret\datasets.py in get_data(dataset, folder, save_copy, profile, verbose, address)
#     130             data = pd.concat([y, X], axis=1)
#     131     else:
# --> 132         raise ValueError("Data could not be read. Please check your inputs...")
#     133
#     134     data = data.infer_objects()
#
# ValueError: Data could not be read. Please check your inputs...

# %%
def get_data(file_name):
    import pandas as pd
    df = pd.read_csv(f"https://raw.githubusercontent.com/EnggQasim/UIT/master/Deep_Learning/Chapter1/data/{file_name}.csv")
    display(df)
    return df

abc = get_data("weight-height")
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
from pycaret.datasets import get_data
data = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
data.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# ...

# %%
from pycaret.classification import *
s = setup(data, target = 'Class variable', session_id = 123)
# Out:
# <style type="text/css">
# #T_a81d4_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a81d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a81d4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a81d4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a81d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a81d4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a81d4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a81d4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a81d4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a81d4_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_a81d4_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# functional API
best = compare_models()

# OOP API
best = s.compare_models()
# Out:
# <style type="text/css">
# #T_beee7 th {
#   text-align: left;
# }
# ...

# %%
abc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
eda()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9572\3763129898.py in <module>
# ----> 1 eda()
#
# ~\AppData\Roaming\Python\Python39\site-packages\pycaret\utils\generic.py in wrapper(*args, **kwargs)
#     963                 if globals_d[name] is None:
#     964                     raise ValueError(message)
# --> 965             return func(*args, **kwargs)
#     966
#     967         return wrapper
#
# ~\AppData\Roaming\Python\Python39\site-packages\pycaret\classification\functional.py in eda(display_format, **kwargs)
#    3088         None
#    3089     """
# -> 3090     return _CURRENT_EXPERIMENT.eda(display_format=display_format, **kwargs)
#    3091
#    3092
#
# ~\AppData\Roaming\Python\Python39\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py in eda(self, display_format, **kwargs)
#    2639         """
#    2640
# ...
